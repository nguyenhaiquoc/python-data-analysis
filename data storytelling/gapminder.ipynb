# %% [markdown]
# Let's begin our EDA process, starting with our categorical variables, continent and country. Let's start with a bar plot to understand the representation of continents in the dataset, so we can answer the following question:

# %%
import plotly
import matplotlib.pyplot as plt

gapminder_data = plotly.data.gapminder()
print(gapminder_data.head())
#Generate a bar plot using the no. of instances of continents
fig = gapminder_data['continent'].value_counts().plot(kind='bar').figure
#Print the no. of instances
print(gapminder_data['continent'].value_counts())
#Label the axes and title
plt.xlabel("Continents")
plt.xticks(rotation=30, horizontalalignment="center")
plt.title("Continents in the Gapminder dataset")
plt.ylabel("Number of instances")
#Show the plot
plt.show()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64

# %%
# drop iso_alpha  and iso_num columns
df = gapminder_data.drop(columns=['iso_alpha', 'iso_num'])
pop_year_df = gapminder_data[['pop', 'year']].sort_values('year')
print(pop_year_df.sample(3))
print(pop_year_df.describe())
import matplotlib.pyplot as plt
# draw line plot
pop_year_df.plot(kind='line', x='year', y='pop')

plt.xlabel('Year')
plt.ylabel('Population Trend Over Time')
plt.show()
group_year = gapminder_data.groupby('year')['pop'].sum()
group_year.plot(kind='line', x='year', y='pop')
plt.xlabel('Year')
plt.ylabel('Population Trend Over Time')
# Out:
#           pop  year
# 521   4738902  1977
# 124   2761407  1972
# 1001  1528000  1977
#                 pop        year
# count  1.704000e+03  1704.00000
# mean   2.960121e+07  1979.50000
# std    1.061579e+08    17.26533
# min    6.001100e+04  1952.00000
# 25%    2.793664e+06  1965.75000
# 50%    7.023596e+06  1979.50000
# 75%    1.958522e+07  1993.25000
# max    1.318683e+09  2007.00000
# Text(0, 0.5, 'Population Trend Over Time')
