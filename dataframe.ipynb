# %% [markdown]
# #### Create data frame from dictionaries

# %%
import pandas as pd
pd.options.display.width = 1000
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
print(df.shape)
# Out:
# (3, 2)

# %% [markdown]
# ### Create dataframe from file

# %%
df = pd.read_csv('sales.csv')
print(df.columns)
print(df.head(5))
# Out:
# Index(['product_code', 'product_group', 'stock_qty', 'cost', 'price', 'last_week_sales', 'last_month_sales'], dtype='object')
#    product_code product_group  stock_qty    cost    price  last_week_sales  last_month_sales
# 0          4187           PG2        498  420.76   569.91               13                58
# 1          4195           PG2        473  545.64   712.41               16                58
# 2          4204           PG2        968  640.42   854.91               22                88
# 3          4219           PG2        241  869.69  1034.55               14                45
# 4          4718           PG2       1401   12.54    26.59               50               285

# %% [markdown]
# **We should think that dataframe is a collection of Series, each Series is a column, rather then think that dataframe is a collection of rows.** (Effective pandas book)

# %%
print(type(df['cost']))
#print(df['cost'])
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ** Distinct unique value in a column **

# %%
cost = df['cost']
print(cost.nunique())
#print(cost.unique())
# Out:
# 682
# [4.2076e+02 5.4564e+02 6.4042e+02 8.6969e+02 1.2540e+01 5.8500e+00
#  9.5600e+00 1.4150e+01 5.9400e+01 6.2600e+00 1.3170e+01 1.6930e+01
#  7.0000e+00 7.6200e+00 8.2300e+00 1.8000e+01 3.8200e+00 1.8180e+01
#  1.8810e+01 2.1950e+01 2.4450e+01 4.9340e+01 3.9470e+01 8.5500e+01
#  8.8860e+01 7.0800e+00 9.6300e+00 5.4900e+00 4.7700e+00 1.2680e+01
#  3.5200e+00 3.4500e+00 7.8500e+00 7.1400e+00 9.4200e+00 5.7200e+00
#  6.4600e+00 2.4100e+00 2.5100e+00 3.5900e+00 2.8300e+00 7.1500e+00
#  8.5400e+00 2.6000e+00 2.7600e+00 1.3600e+00 8.0900e+00 1.1420e+01
#  4.8200e+00 1.0040e+01 1.9800e+00 1.0640e+01 2.5600e+00 4.5500e+01
#  9.3000e+00 7.4100e+00 4.2500e+00 3.9700e+00 2.7960e+01 3.0500e+00
#  6.6600e+00 2.3000e+00 3.2600e+00 1.2000e+00 1.3820e+01 3.4700e+00
#  9.3900e+00 4.6100e+00 1.1340e+01 5.5000e+00 3.1350e+01 3.3060e+01
#  3.9270e+01 8.7100e+00 1.0480e+01 1.2450e+01 1.0510e+01 6.9500e+00
#  4.2850e+01 4.6700e+01 3.5310e+01 1.3200e+01 2.3100e+01 8.2500e+00
# ...
